# %% [markdown]
# <a href="https://colab.research.google.com/github/douglasmmachado/MedicineConsumption/blob/master/notebooks/division_approach/6_Forecasting_Validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 - Forecasting and prediction validation

# %% [markdown]
# ---
#
#
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import math as m

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

from sklearn.tree import export_graphviz
from subprocess import call
from IPython.display import Image

from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error,  mean_absolute_percentage_error
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler

from sklearn.utils import shuffle


df_h1_url ="https://raw.githubusercontent.com/douglasmmachado/ExploratoryDataAnalysis/agglomerative_clustering/datasets/division_approach/clustered/df_h1_clustered.csv"
df_h2_url ="https://raw.githubusercontent.com/douglasmmachado/ExploratoryDataAnalysis/agglomerative_clustering/datasets/division_approach/clustered/df_h2_clustered.csv"
df_h3_url ="https://raw.githubusercontent.com/douglasmmachado/ExploratoryDataAnalysis/agglomerative_clustering/datasets/division_approach/clustered/df_h3_clustered.csv"
df_h4_url ="https://raw.githubusercontent.com/douglasmmachado/ExploratoryDataAnalysis/agglomerative_clustering/datasets/division_approach/clustered/df_h4_clustered.csv"



df_h1 = pd.read_csv(df_h1_url)
df_h1['YEAR'] = df_h1['YEAR'].astype(int)
df_h1['MONTH'] = df_h1['MONTH'].astype(int)
df_h1['DATE'] = pd.to_datetime(df_h1['YEAR'].astype(str) + '-' + df_h1['MONTH'].astype(str), format='%Y-%m')

df_h2 = pd.read_csv(df_h2_url)
df_h2['YEAR'] = df_h2['YEAR'].astype(int)
df_h2['MONTH'] = df_h2['MONTH'].astype(int)
df_h2['DATE'] = pd.to_datetime(df_h2['YEAR'].astype(str) + '-' + df_h2['MONTH'].astype(str), format='%Y-%m')

df_h3 = pd.read_csv(df_h3_url)
df_h3['YEAR'] = df_h3['YEAR'].astype(int)
df_h3['MONTH'] = df_h3['MONTH'].astype(int)
df_h3['DATE'] = pd.to_datetime(df_h3['YEAR'].astype(str) + '-' + df_h3['MONTH'].astype(str), format='%Y-%m')

df_h4 = pd.read_csv(df_h4_url)
df_h4['YEAR'] = df_h4['YEAR'].astype(int)
df_h4['MONTH'] = df_h4['MONTH'].astype(int)
df_h4['DATE'] = pd.to_datetime(df_h4['YEAR'].astype(str) + '-' + df_h4['MONTH'].astype(str), format='%Y-%m')

# %%
df_h1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CODE_ATC        525 non-null    int64
#  1   DATE            525 non-null    datetime64[ns]
#  2   HOSPI_CODE_UCD  525 non-null    int64
#  3   LIT_HC          525 non-null    float64
#  4   LIT_HP          525 non-null    float64
#  5   MONTH           525 non-null    int64
#  6   N_UFS           525 non-null    float64
#  7   PN_MEDICAL      525 non-null    float64
#  8   POPULATION      525 non-null    float64
#  9   P_MEDICAL       525 non-null    float64
#  10  QUANTITY        525 non-null    float64
#  11  QUANTITY_MA     525 non-null    float64
#  12  SEJ_MCO         525 non-null    float64
#  13  SEJ_SLD         525 non-null    float64
#  14  SEJ_SSR         525 non-null    float64
#  15  WEEK            525 non-null    int64
#  16  YEAR            525 non-null    int64
#  17  CLUSTER         525 non-null    int64
# dtypes: datetime64[ns](1), float64(11), int64(6)
# memory usage: 74.0 KB

# %%
df_h2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CODE_ATC        525 non-null    int64
#  1   DATE            525 non-null    datetime64[ns]
#  2   HOSPI_CODE_UCD  525 non-null    int64
#  3   LIT_HC          525 non-null    float64
#  4   LIT_HP          525 non-null    float64
#  5   MONTH           525 non-null    int64
#  6   N_UFS           525 non-null    float64
#  7   PN_MEDICAL      525 non-null    float64
#  8   POPULATION      525 non-null    float64
#  9   P_MEDICAL       525 non-null    float64
#  10  QUANTITY        525 non-null    float64
#  11  QUANTITY_MA     525 non-null    float64
#  12  SEJ_MCO         525 non-null    float64
#  13  SEJ_PSY         525 non-null    float64
#  14  SEJ_SSR         525 non-null    float64
#  15  WEEK            525 non-null    int64
#  16  YEAR            525 non-null    int64
#  17  CLUSTER         525 non-null    int64
# dtypes: datetime64[ns](1), float64(11), int64(6)
# memory usage: 74.0 KB

# %%
df_h3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CODE_ATC        525 non-null    int64
#  1   DATE            525 non-null    datetime64[ns]
#  2   HOSPI_CODE_UCD  525 non-null    int64
#  3   LIT_HC          525 non-null    float64
#  4   LIT_HP          525 non-null    float64
#  5   MONTH           525 non-null    int64
#  6   N_UFS           525 non-null    float64
#  7   PN_MEDICAL      525 non-null    float64
#  8   POPULATION      525 non-null    float64
#  9   P_MEDICAL       525 non-null    float64
#  10  QUANTITY        525 non-null    float64
#  11  QUANTITY_MA     525 non-null    float64
#  12  SEJ_HAD         525 non-null    float64
#  13  SEJ_MCO         525 non-null    float64
#  14  SEJ_PSY         525 non-null    float64
#  15  SEJ_SLD         525 non-null    float64
#  16  SEJ_SSR         525 non-null    float64
#  17  WEEK            525 non-null    int64
#  18  YEAR            525 non-null    int64
#  19  CLUSTER         525 non-null    int64
# dtypes: datetime64[ns](1), float64(13), int64(6)
# memory usage: 82.2 KB

# %%
df_h4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CODE_ATC        525 non-null    int64
#  1   DATE            525 non-null    datetime64[ns]
#  2   HOSPI_CODE_UCD  525 non-null    int64
#  3   LIT_HC          525 non-null    float64
#  4   LIT_HP          525 non-null    float64
#  5   MONTH           525 non-null    int64
#  6   N_UFS           525 non-null    float64
#  7   PN_MEDICAL      525 non-null    float64
#  8   POPULATION      525 non-null    float64
#  9   P_MEDICAL       525 non-null    float64
#  10  QUANTITY        525 non-null    float64
#  11  QUANTITY_MA     525 non-null    float64
#  12  SEJ_MCO         525 non-null    float64
#  13  SEJ_PSY         525 non-null    float64
#  14  SEJ_SLD         525 non-null    float64
#  15  SEJ_SSR         525 non-null    float64
#  16  WEEK            525 non-null    int64
#  17  YEAR            525 non-null    int64
#  18  CLUSTER         525 non-null    int64
# dtypes: datetime64[ns](1), float64(12), int64(6)
# memory usage: 78.1 KB

# %% [markdown]
# ## 6.1 - New database composition based on clusters

# %%
df_h1_cluster_0 = df_h1[df_h1['CLUSTER'] == 0].copy()
df_h1_cluster_1 = df_h1[df_h1['CLUSTER'] == 1].copy()
df_h1_cluster_2 = df_h1[df_h1['CLUSTER'] == 2].copy()
df_h1_cluster_3 = df_h1[df_h1['CLUSTER'] == 3].copy()

# %%
df_h2_cluster_0 = df_h2[df_h2['CLUSTER'] == 0].copy()
df_h2_cluster_1 = df_h2[df_h2['CLUSTER'] == 1].copy()
df_h2_cluster_2 = df_h2[df_h2['CLUSTER'] == 2].copy()
df_h2_cluster_3 = df_h2[df_h2['CLUSTER'] == 3].copy()

# %%
df_h3_cluster_0 = df_h3[df_h3['CLUSTER'] == 0].copy()
df_h3_cluster_1 = df_h3[df_h3['CLUSTER'] == 1].copy()
df_h3_cluster_2 = df_h3[df_h3['CLUSTER'] == 2].copy()
df_h3_cluster_3 = df_h3[df_h3['CLUSTER'] == 3].copy()

# %%
df_h4_cluster_0 = df_h4[df_h4['CLUSTER'] == 0].copy()
df_h4_cluster_1 = df_h4[df_h4['CLUSTER'] == 1].copy()
df_h4_cluster_2 = df_h4[df_h4['CLUSTER'] == 2].copy()
df_h4_cluster_3 = df_h4[df_h4['CLUSTER'] == 3].copy()

# %% [markdown]
# ## 6.2 - Baseline score, Test 1

# %%
def test_1_baseline(df, medicine, df_scores, hospital = '-', unified = False):

  df = df.fillna(0)
  scaler = StandardScaler()

  X = df[df['HOSPI_CODE_UCD'] == medicine].drop(['QUANTITY', 'DATE', 'WEEK', 'CLUSTER'], axis=1).copy().values
  X_scaled = scaler.fit_transform(X)

  y = df[df['HOSPI_CODE_UCD'] == medicine]['QUANTITY'].copy().values

  if unified:
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.35, random_state=42, shuffle = True)

  else:
    X_train = X_scaled
    X_test = X_scaled
    y_train = y
    y_test = y

  # Define the parameter distributions for RandomizedSearchCV
  param_distributions = {
      'max_depth': np.arange(2, 31, 2),
      'n_estimators': np.arange(2, 201, 2),
      'max_features': ['sqrt', 'log2'],
      'min_samples_split': np.arange(2, 11, 2),
      'min_samples_leaf': np.arange(2, 5, 1)
  }

  # Create the RandomizedSearchCV object
  randomized_search = RandomizedSearchCV(estimator=RandomForestRegressor(random_state=42),
                                          param_distributions=param_distributions,
                                          n_iter=100,
                                          cv=5,
                                          random_state=42)

  # Fit the RandomizedSearchCV object to the data
  randomized_search.fit(X_train, y_train)

  # Get the best estimator
  best_estimator = randomized_search.best_estimator_

  # Make predictions using the best estimator
  y_pred = best_estimator.predict(X_test)

  # Calculate R^2 score
  r2 = r2_score(y_test, y_pred)

  # Calculate MAE
  mae = mean_absolute_error(y_test, y_pred)

  # Calculate MAPE
  mape = mean_absolute_percentage_error(y_test, y_pred)

  # Calculate RMSE
  rmse = np.sqrt(mean_squared_error(y_test, y_pred))

  # Print the best parameters, best score, and evaluation metrics
  print('Medicine:' + str(medicine))
  print('Best Parameters:', randomized_search.best_params_)
  print('Best Score:', randomized_search.best_score_)
  print('R^2 Score:', round(r2, 3))
  print('MAE:', round(mae, 3))
  print('MAPE:', round(mape, 3))
  print('RMSE:', round(rmse, 3))
  print()


  # Create the new row as a DataFrame
  new_row = pd.DataFrame({'ID_SITE_RATTACHE': [hospital],
                          'HOSPI_CODE_UCD': ['CODE_UCD_'+str(medicine)],
                          'R2': [r2],
                          'RMSE': [rmse],
                          'MAE': [mae],
                          'MAPE': [mape]})

  # Append the new row to the DataFrame
  df_scores = pd.concat([df_scores, new_row], ignore_index=True)

  # Return the updated DataFrame
  return df_scores

# %%
df_prediction_scores_h1 = pd.DataFrame(columns=['ID_SITE_RATTACHE', 'HOSPI_CODE_UCD', 'R2', 'RMSE', 'MAE', 'MAPE'])

for medicine in df_h1.HOSPI_CODE_UCD.unique():

  df_prediction_scores_h1 = test_1_baseline(df_h1, medicine, df_prediction_scores_h1, hospital = 'HOSPI_1', unified = False)

df_prediction_scores_h1

df_prediction_scores_h1.to_csv('df_prediction_scores_h1.csv')
# Out:
# Medicine:3400890837149
# Best Parameters: {'n_estimators': 56, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 8}
# Best Score: -0.9345859727694268
# R^2 Score: 0.551
# MAE: 96.027
# MAPE: 0.035
# RMSE: 144.669
#
# Medicine:3400893826706
# Best Parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 28}
# Best Score: -0.10578437610201927
# R^2 Score: 0.469
# MAE: 268.737
# MAPE: 0.094
# RMSE: 382.393
#
# Medicine:3400892729589
# Best Parameters: {'n_estimators': 34, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': 8}
# Best Score: -0.10257021896869647
# R^2 Score: 0.385
# MAE: 417.36
# MAPE: 0.13
# RMSE: 575.272
#
# Medicine:3400892088310
# Best Parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 28}
# Best Score: -20.30800255519136
# R^2 Score: 0.486
# MAE: 188.153
# MAPE: 0.077
# RMSE: 241.974
#
# Medicine:3400892075761
# Best Parameters: {'n_estimators': 200, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 2}
# Best Score: -0.002643782988326837
# R^2 Score: 0.415
# MAE: 96.375
# MAPE: 0.075
# RMSE: 126.185
#
# Medicine:3400892745848
# Best Parameters: {'n_estimators': 188, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 20}
# Best Score: -0.6676390945568085
# R^2 Score: 0.66
# MAE: 491.26
# MAPE: 0.078
# RMSE: 694.815
#
# Medicine:3400893736135
# Best Parameters: {'n_estimators': 56, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 8}
# Best Score: 0.28032542338501315
# R^2 Score: 0.562
# MAE: 152.807
# MAPE: 0.081
# RMSE: 192.285
#
# Medicine:3400892697789
# Best Parameters: {'n_estimators': 10, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': 28}
# Best Score: -0.651997752140292
# R^2 Score: 0.347
# MAE: 133.644
# MAPE: 0.14
# RMSE: 173.31
#
# Medicine:3400892203645
# Best Parameters: {'n_estimators': 2, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 18}
# Best Score: -0.21051657505979052
# R^2 Score: 0.262
# MAE: 114.523
# MAPE: 0.087
# RMSE: 145.7
#
# Medicine:3400891235203
# Best Parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 28}
# Best Score: -3.576432266328608
# R^2 Score: 0.886
# MAE: 177.548
# MAPE: 2.046940786118018e+17
# RMSE: 214.011
#
# Medicine:3400891225037
# Best Parameters: {'n_estimators': 148, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 30}
# Best Score: 0.15811973834674212
# R^2 Score: 0.627
# MAE: 595.16
# MAPE: 0.037
# RMSE: 804.332
#
# Medicine:3400893875490
# Best Parameters: {'n_estimators': 82, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': 22}
# Best Score: 0.04382598952727792
# R^2 Score: 0.268
# MAE: 432.056
# MAPE: 0.048
# RMSE: 641.014
#
# Medicine:3400892065366
# Best Parameters: {'n_estimators': 2, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 18}
# Best Score: -0.0797472114874199
# R^2 Score: 0.204
# MAE: 225.914
# MAPE: 0.047
# RMSE: 276.61
#
# Medicine:3400892761527
# Best Parameters: {'n_estimators': 178, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 28}
# Best Score: -0.27874409892072577
# R^2 Score: 0.626
# MAE: 707.412
# MAPE: 0.499
# RMSE: 915.629
#
# Medicine:3400893022634
# Best Parameters: {'n_estimators': 178, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 28}
# Best Score: -0.050939536745024674
# R^2 Score: 0.541
# MAE: 178.787
# MAPE: 0.058
# RMSE: 243.736
#
# Medicine:3400891191226
# Best Parameters: {'n_estimators': 104, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 22}
# Best Score: 0.041600921772686664
# R^2 Score: 0.55
# MAE: 148.267
# MAPE: 0.056
# RMSE: 191.502
#
# Medicine:3400892761695
# Best Parameters: {'n_estimators': 172, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10}
# Best Score: -0.5747178586043069
# R^2 Score: 0.518
# MAE: 95.397
# MAPE: 0.059
# RMSE: 127.072
#
# Medicine:3400892669236
# Best Parameters: {'n_estimators': 10, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': 28}
# Best Score: -0.2698312232004609
# R^2 Score: 0.737
# MAE: 1671.632
# MAPE: 2.595014237367559e+18
# RMSE: 2337.134
#
# Medicine:3400892508566
# Best Parameters: {'n_estimators': 188, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 20}
# Best Score: -0.012069638017412542
# R^2 Score: 0.598
# MAE: 404.107
# MAPE: 0.124
# RMSE: 514.674
#
# Medicine:3400892052120
# Best Parameters: {'n_estimators': 96, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 2}
# Best Score: -0.45288546905394256
# R^2 Score: 0.175
# MAE: 221.858
# MAPE: 0.089
# RMSE: 320.704
#
# Medicine:3400891996128
# Best Parameters: {'n_estimators': 56, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': 20}
# Best Score: -0.0909437798243955
# R^2 Score: 0.323
# MAE: 2831.149
# MAPE: 0.052
# RMSE: 3849.636

# %%
df_prediction_scores_h2 = pd.DataFrame(columns=['ID_SITE_RATTACHE', 'HOSPI_CODE_UCD', 'R2', 'RMSE', 'MAE', 'MAPE'])

for medicine in df_h2.HOSPI_CODE_UCD.unique():

  df_prediction_scores_h2 = test_1_baseline(df_h2, medicine, df_prediction_scores_h2, hospital = 'HOSPI_2', unified = False)

df_prediction_scores_h2

df_prediction_scores_h2.to_csv('df_prediction_scores_h2.csv')
# Out:
# Medicine:3400890837149
# Best Parameters: {'n_estimators':
#
# Medicine:3400892075761
# Best Parameters: {'n_estimators': 56, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': 20}
# Best Score: -1.722123016198
# R^2 Score: 0.404
# MAE: 729.371
# MAPE: 0.085
# RMSE: 921.638
#
# Medicine:3400892745848
# Best Parameters: {'n_estimators': 4, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 30}
# Best Score: -0.8726506741009048
# R^2 Score: 0.172
# MAE: 1885.298
# MAPE: 0.183
# RMSE: 2447.999
#
# Medicine:3400893736135
# Best Parameters: {'n_estimators': 10, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': 28}
# Best Score: -0.200228848105312
# R^2 Score: 0.204
# MAE: 1044.544
# MAPE: 0.138
# RMSE: 1240.491
#
# Medicine:3400892697789
# Best Parameters: {'n_estimators': 188, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 20}
# Best Score: -0.13431659557481065
# R^2 Score: 0.435
# MAE: 764.891
# MAPE: 0.066
# RMSE: 1005.934
#
# Medicine:3400892203645
# Best Parameters: {'n_estimators': 4, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 30}
# Best Score: 0.023953811412045757
# R^2 Score: 0.195
# MAE: 887.264
# MAPE: 0.095
# RMSE: 1117.695
#
# Medicine:3400891235203
# Best Parameters: {'n_estimators': 56, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 8}
# Best Score: 0.13846282390351516
# R^2 Score: 0.559
# MAE: 661.519
# MAPE: 0.122
# RMSE: 854.175
#
# Medicine:3400891225037
# Best Parameters: {'n_estimators': 56, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 8}
# Best Score: -1.0232547526100473
# R^2 Score: 0.606
# MAE: 1396.5
# MAPE: 0.056
# RMSE: 1701.178
#
# Medicine:3400893875490
# Best Parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 28}
# Best Score: 0.016116124184957448
# R^2 Score: 0.457
# MAE: 1463.748
# MAPE: 0.069
# RMSE: 1987.55
#
# Medicine:3400892065366
# Best Parameters: {'n_estimators': 42, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 24}
# Best Score: -0.9613720666239598
# R^2 Score: 0.282
# MAE: 1485.588
# MAPE: 0.076
# RMSE: 1917.987
#
# Medicine:3400892761527
# Best Parameters: {'n_estimators': 24, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': 4}
# Best Score: -0.12323355240416962
# R^2 Score: 0.198
# MAE: 902.437
# MAPE: 0.155
# RMSE: 1237.23
#
# Medicine:3400893022634
# Best Parameters: {'n_estimators': 2, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 18}
# Best Score: 0.38725287000091424
# R^2 Score: 0.552
# MAE: 450.377
# MAPE: 9.890511035501603e+17
# RMSE: 677.189
#
# Medicine:3400891191226
# Best Parameters: {'n_estimators': 2, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 18}
# Best Score: -2.2025599282412225
# R^2 Score: 0.26
# MAE: 749.511
# MAPE: 0.088
# RMSE: 917.188
#
# Medicine:3400892761695
# Best Parameters: {'n_estimators': 2, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 18}
# Best Score: 0.08637318738248097
# R^2 Score: 0.291
# MAE: 936.843
# MAPE: 0.111
# RMSE: 1140.123
#
# Medicine:3400892669236
# Best Parameters: {'n_estimators': 48, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 12}
# Best Score: -0.4028215802237688
# R^2 Score: 0.359
# MAE: 2851.865
# MAPE: 0.119
# RMSE: 3810.167
#
# Medicine:3400892508566
# Best Parameters: {'n_estimators': 42, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 24}
# Best Score: -0.9166758646901751
# R^2 Score: 0.263
# MAE: 790.633
# MAPE: 0.115
# RMSE: 984.581
#
# Medicine:3400892052120
# Best Parameters: {'n_estimators': 4, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 30}
# Best Score: -1.036462656425595
# R^2 Score: 0.237
# MAE: 870.922
# MAPE: 0.115
# RMSE: 1202.404
#
# Medicine:3400891996128
# Best Parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 28}
# Best Score: -0.10264238304890434
# R^2 Score: 0.629
# MAE: 9822.288
# MAPE: 0.046
# RMSE: 14621.454

# %%
df_prediction_scores_unified = pd.DataFrame(columns=['ID_SITE_RATTACHE', 'HOSPI_CODE_UCD', 'R2', 'RMSE', 'MAE', 'MAPE'])

df_unified = pd.concat([df_h1,df_h2,df_h3, df_h4])

for medicine in df_unified.HOSPI_CODE_UCD.unique():

  df_prediction_scores_unified = test_1_baseline(df_unified, medicine, df_prediction_scores_unified, hospital = '-', unified = True)

df_prediction_scores_unified.to_csv('df_prediction_scores_unified.csv')
# Out:
# Medicine:3400890837149
# Best Parameters: {'n_estimators': 150, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 30}
# Best Score: 0.9679595902171432
# R^2 Score: 0.974
# MAE: 566.924
# MAPE: 0.085
# RMSE: 983.941
#
# Medicine:3400893826706
# Best Parameters: {'n_estimators': 34, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': 8}
# Best Score: 0.8546861200438457
# R^2 Score: 0.902
# MAE: 553.042
# MAPE: 0.136
# RMSE: 765.646
#
# Medicine:3400892729589
# Best Parameters: {'n_estimators': 36, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 10}
# Best Score: 0.9424415434671003
# R^2 Score: 0.926
# MAE: 944.625
# MAPE: 0.147
# RMSE: 1543.928
#
# Medicine:3400892088310
# Best Parameters: {'n_estimators': 104, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 18}
# Best Score: 0.49819016877091976
# R^2 Score: 0.886
# MAE: 427.05
# MAPE: 0.107
# RMSE: 574.171
#
# Medicine:3400892075761
# Best Parameters: {'n_estimators': 2, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 18}
# Best Score: 0.9549390043491177
# R^2 Score: 0.905
# MAE: 525.206
# MAPE: 0.126
# RMSE: 932.714
#
# Medicine:3400892745848
# Best Parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 28}
# Best Score: 0.9103006774910488
# R^2 Score: 0.845
# MAE: 943.727
# MAPE: 0.186
# RMSE: 1650.788
#
# Medicine:3400893736135
# Best Parameters: {'n_estimators': 116, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 14}
# Best Score: 0.8258519841079316
# R^2 Score: 0.887
# MAE: 522.484
# MAPE: 0.104
# RMSE: 709.906
#
# Medicine:3400892697789
# Best Parameters: {'n_estimators': 170, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': 8}
# Best Score: 0.9933974044586555
# R^2 Score: 0.948
# MAE: 611.952
# MAPE: 0.158
# RMSE: 1114.765
#
# Medicine:3400892203645
# Best Parameters: {'n_estimators': 24, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': 4}
# Best Score: 0.9354547081286467
# R^2 Score: 0.907
# MAE: 618.573
# MAPE: 0.135
# RMSE: 903.246
#
# Medicine:3400891235203
# Best Parameters: {'n_estimators': 114, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': 4}
# Best Score: 0.8636951173344679
# R^2 Score: 0.924
# MAE: 414.553
# MAPE: 5.489550041528531e+16
# RMSE: 645.639
#
# Medicine:3400891225037
# Best Parameters: {'n_estimators': 2, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 18}
# Best Score: 0.8305822786590857
# R^2 Score: 0.851
# MAE: 1979.715
# MAPE: 0.115
# RMSE: 2364.46
#
# Medicine:3400893875490
# Best Parameters: {'n_estimators': 42, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 24}
# Best Score: 0.9344042756678208
# R^2 Score: 0.916
# MAE: 891.068
# MAPE: 0.061
# RMSE: 1606.788
#
# Medicine:3400892065366
# Best Parameters: {'n_estimators': 104, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 22}
# Best Score: 0.9275870205178487
# R^2 Score: 0.949
# MAE: 912.869
# MAPE: 0.098
# RMSE: 1323.123
#
# Medicine:3400892761527
# Best Parameters: {'n_estimators': 88, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 16}
# Best Score: 0.9715261517671644
# R^2 Score: 0.959
# MAE: 1329.579
# MAPE: 0.149
# RMSE: 1744.997
#
# Medicine:3400893022634
# Best Parameters: {'n_estimators': 14, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 28}
# Best Score: 0.854200754131748
# R^2 Score: 0.894
# MAE: 468.479
# MAPE: 3.103473812419652e+17
# RMSE: 608.866
#
# Medicine:3400891191226
# Best Parameters: {'n_estimators': 24, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': 4}
# Best Score: 0.954304276633849
# R^2 Score: 0.912
# MAE: 516.602
# MAPE: 0.087
# RMSE: 803.893
#
# Medicine:3400892761695
# Best Parameters: {'n_estimators': 6, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 10}
# Best Score: 0.9789027464066145
# R^2 Score: 0.981
# MAE: 827.546
# MAPE: 0.09
# RMSE: 1142.7
#
# Medicine:3400892669236
# Best Parameters: {'n_estimators': 34, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': 8}
# Best Score: 0.8525618427984305
# R^2 Score: 0.922
# MAE: 1523.672
# MAPE: 4.195715184508096e+17
# RMSE: 2248.51
#
# Medicine:3400892508566
# Best Parameters: {'n_estimators': 10, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': 28}
# Best Score: 0.8680302638385295
# R^2 Score: 0.899
# MAE: 589.798
# MAPE: 3.2025272415152144e+16
# RMSE: 906.177
#
# Medicine:3400892052120
# Best Parameters: {'n_estimators': 56, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 8}
# Best Score: 0.931680632132234
# R^2 Score: 0.967
# MAE: 325.732
# MAPE: 0.091
# RMSE: 535.147
#
# Medicine:3400891996128
# Best Parameters: {'n_estimators': 64, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 14}
# Best Score: 0.9511525529345226
# R^2 Score: 0.956
# MAE: 7826.733
# MAPE: 0.073
# RMSE: 12471.611

# %% [markdown]
# ## 6.3 - Clustering score, Test 2

# %% [markdown]
# ### Hospital 1 - Cluster 0
